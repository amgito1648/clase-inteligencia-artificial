# %% [markdown]
# <a href="https://colab.research.google.com/github/amgito1648/clase-inteligencia-artificial/blob/main/Cuaderno_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 25-03-2025
# sopor vector machine
# sopor vector clasifier. clasificaciones
#
# sopor vector regresion.  regresiones
#
# predecir si vamos a pasar o perder el saber 11, clasifier 0 o 1 pasa o pierde
#
# saber cual es la nota de puntaje total de saber 11(regresion)
#
# si quiero saber cual es la variable de clasificacion PM 2.5 (clasificaciones)
#
# predecir la calidad del aire, buena, saludable, no saludable, dañino ( clasifier)
#
# predecir si el dolar mañana esta con tendencia al alta o baja (clasifier)
# predecir valor del dolar (regresion)
#
#
# predecir a que edad se va a morir (regresion)
#
#
# #crear un nuevo feature, elevando al cuadrado alguno de los features
# truco del kernel, buscar una manera atravez de dumies, crar un ponomio de las columnas actuales para predecir y que queden linealmente separables.
#
# kernel Gaussiano (RBF) si no es lineal.
#
# para que sirve el label encoder
# para dejar los datos en 0 y 1 numerizar.
#
# y normalizar.
# cuando se utiliza onehot encoder ()
#
# Categoricas (ordinal, booleana, nominal)  para variables ordinales. ordinal encoders
#
# nominal no hay orden, variables dummies, one hot encoder.
#
# por frecuencia()
#
# y cuando label encoder ( es el menos recomendado, trata las variables como si fueran ordinales, pero sin orden) niños, joven, adultos, viejos
#
# encuentra primero al viejo, 0, niño, 2  , adultos 3 y joven 4.
#
# error medio cuadratico ( regresion)
#
# de donde se calcula el acuraccy la sumatoria de verdaderos positivos + verdaderos negativos / el total de  los reales.
#
#
# clasificacion.

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
import pandas as pd

data = {
    "Horas de Estudio": ["Alta", "Baja", "Baja", "Alta", "Alta"],
    "Asistencia": ["Buena", "Buena", "Mala", "Mala", "Buena"],
    "Resultado": ["Sí", "No", "No", "Sí", "Sí"]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#   Horas de Estudio Asistencia Resultado
# 0             Alta      Buena        Sí
# 1             Baja      Buena        No
# 2             Baja       Mala        No
# 3             Alta       Mala        Sí
# 4             Alta      Buena        Sí

# %%
# Codificadores separados para cada característica y la etiqueta
encoder_estudio = LabelEncoder()
encoder_asistencia = LabelEncoder()

df["Horas de Estudio"] = encoder_estudio.fit_transform(df["Horas de Estudio"])
df["Asistencia"] = encoder_asistencia.fit_transform(df["Asistencia"])

# Codificar la etiqueta de resultado
y_encoder = LabelEncoder()
df["Resultado"] = y_encoder.fit_transform(df["Resultado"])

# %%
df
# Out:
#    Horas de Estudio  Asistencia  Resultado
# 0                 0           0          1
# 1                 1           0          0
# 2                 1           1          0
# 3                 0           1          1
# 4                 0           0          1

# %%
X = df[["Horas de Estudio", "Asistencia"]]
y = df["Resultado"]

# %%
from sklearn.svm import SVC

model = SVC(kernel='linear')
model.fit(X, y)
# Out:
# SVC(kernel='linear')

# %%
new_observation = pd.DataFrame({
    "Horas de Estudio": [encoder_estudio.transform(["Alta"])[0]],  # Usar encoder_estudio
    "Asistencia": [encoder_asistencia.transform(["Mala"])[0]]    # Usar encoder_asistencia
})

prediction = model.predict(new_observation)
predicted_label = y_encoder.inverse_transform(prediction)
print("Predicción:", predicted_label[0])
# Out:
# Predicción: Sí
